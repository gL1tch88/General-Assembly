# %%
import requests
from bs4 import BeautifulSoup
# Commented out from Win environment
# from scrapy.selector import Selector
import lxml
import pandas as pd
import re
import time
import random

# %matplotlib inline

# %%
job_site = 'https://au.indeed.com'
start_page = '&start='
page_count = ''
counter = 50
store_job = []
next_button_len = 2

# %%
url_indeed = 'https://au.indeed.com/jobs?q=%28python+or+sql%29++%28data+or+scientist+or+science+or+analyst+or+research+or+business+or+intelligence+or+analytics+or+statistics+or+Actuarial+or+actuary+or+%22data+engineer%22%29+-developer%2C+-clerk%2C+-software%2C+-network%2C+-security%2C+-programmer&sort=date&radius=50&limit=50'
# url_indeed = 'https://au.indeed.com/jobs?as_and=%27data+scientist%27&as_phr=&as_any=&as_not=&as_ttl=&as_cmp=&jt=all&st=&as_src=&salary=&radius=100&l=Sydney&fromage=any&limit=50&sort=&psf=advsrch&from=advancedsearch'

# %%
ua_source_url='https://deviceatlas.com/blog/list-of-user-agent-strings#desktop'

# %%
def get_ua_list(source=ua_source_url):
    r = requests.get(source)
    soup = BeautifulSoup(r.content, "html.parser")
    tables = soup.find_all('table')
    return [table.find('td').text for table in tables]

# %%
def delay() -> None:
    time.sleep(random.uniform(15, 30))
    return None

# %%
random.choice(get_ua_list())
# Out:
# 'Mozilla/5.0 (Linux; Android 7.0; SM-G930VC Build/NRD90M; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/58.0.3029.83 Mobile Safari/537.36'

# %%
def soup_req(url):
#     user_agent = random.choice(get_ua_list())
    req = requests.get(url)
    soup = BeautifulSoup(req.content,features='lxml')
    
    return soup

# %%
soup_indeed = soup_req(url_indeed)
# link_indeed = soup_indeed.find_all('div', {'class': 'title'})
link_indeed = soup_indeed.find_all('div', class_='result')

# %%
link_indeed
# Out:
# [<div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="fdb0eee77578e8cf" data-tn-component="organicJob" id="p_fdb0eee77578e8cf">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=fdb0eee77578e8cf&amp;fccid=bca6f10d73dbbf6c&amp;vjs=3" id="jl_fdb0eee77578e8cf" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[0],true,1);" onmousedown="return rclk(this,jobmap[0],1);" rel="noopener nofollow" target="_blank" title="Analyst, Business Intelligence">
#  <b>Analyst</b>, <b>Business</b> <b>Intelligence</b></a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Macquarie-University" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=fdb0eee77578e8cf&amp;jcid=bca6f10d73dbbf6c')" rel="noopener" target="_blank">
#  Macquarie University</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Macquarie-University/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Analyst%2C+Business+Intelligence&amp;fromjk=fdb0eee77578e8cf&amp;jcid=bca6f10d73dbbf6c');" rel="noopener" target="_blank" title="Macquarie University reviews">
#  <span class="ratingsContent">
#  4.4<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Macquarie University NSW" id="recJobLoc_fdb0eee77578e8cf" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Macquarie University NSW</span>
#  </div>
#  <div class="salarySnippet salarySnippetDemphasizeholisticSalary">
#  <span class="salary no-wrap">
#  <span class="salaryText">
#  $83,478 - $92,146 a year</span>
#  </span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li style="margin-bottom:0px;">Become the owner of our <b>business</b> critical financial reports.</li>
#  <li>Exposure to <b>data</b> management, preferably in a B.I. environment.</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_0"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_fdb0eee77578e8cf" onclick="changeJobState('fdb0eee77578e8cf', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_0" onclick="toggleMoreLinks('fdb0eee77578e8cf'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_fdb0eee77578e8cf" style="display:none;"></div><script>if (!window['result_fdb0eee77578e8cf']) {window['result_fdb0eee77578e8cf'] = {};}window['result_fdb0eee77578e8cf']['showSource'] = false; window['result_fdb0eee77578e8cf']['source'] = "Macquarie University"; window['result_fdb0eee77578e8cf']['loggedIn'] = false; window['result_fdb0eee77578e8cf']['showMyJobsLinks'] = false;window['result_fdb0eee77578e8cf']['undoAction'] = "unsave";window['result_fdb0eee77578e8cf']['relativeJobAge'] = "Just posted";window['result_fdb0eee77578e8cf']['jobKey'] = "fdb0eee77578e8cf"; window['result_fdb0eee77578e8cf']['myIndeedAvailable'] = true; window['result_fdb0eee77578e8cf']['showMoreActionsLink'] = window['result_fdb0eee77578e8cf']['showMoreActionsLink'] || true; window['result_fdb0eee77578e8cf']['resultNumber'] = 0; window['result_fdb0eee77578e8cf']['jobStateChangedToSaved'] = false; window['result_fdb0eee77578e8cf']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['result_fdb0eee77578e8cf']['basicPermaLink'] = "https://au.indeed.com"; window['result_fdb0eee77578e8cf']['saveJobFailed'] = false; window['result_fdb0eee77578e8cf']['removeJobFailed'] = false; window['result_fdb0eee77578e8cf']['requestPending'] = false; window['result_fdb0eee77578e8cf']['notesEnabled'] = true; window['result_fdb0eee77578e8cf']['currentPage'] = "serp"; window['result_fdb0eee77578e8cf']['sponsored'] = false;window['result_fdb0eee77578e8cf']['reportJobButtonEnabled'] = false; window['result_fdb0eee77578e8cf']['showMyJobsHired'] = false; window['result_fdb0eee77578e8cf']['showSaveForSponsored'] = false; window['result_fdb0eee77578e8cf']['showJobAge'] = true; window['result_fdb0eee77578e8cf']['showHolisticCard'] = true; window['result_fdb0eee77578e8cf']['showDislike'] = false; window['result_fdb0eee77578e8cf']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="more-links-container result-tab" id="tt_display_0" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('fdb0eee77578e8cf'); return false;" title="Close"></a><div class="more_actions" id="more_0"><ul><li><span class="mat">View all <a href="/Macquarie-University-jobs">Macquarie University jobs</a> - <a href="/jobs-in-Macquarie-University-NSW">Macquarie University jobs</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Macquarie-University" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=fdb0eee77578e8cf&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=bca6f10d73dbbf6c');">Macquarie University</a></span></li><li><span class="mat">See popular <a href="/cmp/Macquarie-University/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=fdb0eee77578e8cf&amp;jcid=bca6f10d73dbbf6c');">questions &amp; answers about Macquarie University</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  <div class="sign-in-container result-tab"></div>
#  <div class="notes-container result-tab"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="aaa818ee5983f7b9" data-tn-component="organicJob" id="p_aaa818ee5983f7b9">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=aaa818ee5983f7b9&amp;fccid=033d5c6dd090c8a4&amp;vjs=3" id="jl_aaa818ee5983f7b9" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="noopener nofollow" target="_blank" title="Principal Business Analyst">
#  Principal <b>Business</b> <b>Analyst</b></a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Queensland-Government" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=aaa818ee5983f7b9&amp;jcid=033d5c6dd090c8a4')" rel="noopener" target="_blank">
#  Queensland Government</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Queensland-Government/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Principal+Business+Analyst&amp;fromjk=aaa818ee5983f7b9&amp;jcid=033d5c6dd090c8a4');" rel="noopener" target="_blank" title="Queensland Government reviews">
#  <span class="ratingsContent">
#  4.0<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Logan City QLD" id="recJobLoc_aaa818ee5983f7b9" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Logan City QLD</span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li>Gather <b>data</b> from <b>business</b> systems and undertake straight-forward analysis to inform senior managers' deliberations about <b>business</b> performance metrics and…</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_1"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_aaa818ee5983f7b9" onclick="changeJobState('aaa818ee5983f7b9', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_1" onclick="toggleMoreLinks('aaa818ee5983f7b9'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_aaa818ee5983f7b9" style="display:none;"></div><script>if (!window['result_aaa818ee5983f7b9']) {window['result_aaa818ee5983f7b9'] = {};}window['result_aaa818ee5983f7b9']['showSource'] = false; window['result_aaa818ee5983f7b9']['source'] = "Queensland Government"; window['result_aaa818ee5983f7b9']['loggedIn'] = false; window['result_aaa818ee5983f7b9']['showMyJobsLinks'] = false;window['result_aaa818ee5983f7b9']['undoAction'] = "unsave";window['result_aaa818ee5983f7b9']['relativeJobAge'] = "Just posted";window['result_aaa818ee5983f7b9']['jobKey'] = "aaa818ee5983f7b9"; window['result_aaa818ee5983f7b9']['myIndeedAvailable'] = true; window['result_aaa818ee5983f7b9']['showMoreActionsLink'] = window['result_aaa818ee5983f7b9']['showMoreActionsLink'] || true; window['result_aaa818ee5983f7b9']['resultNumber'] = 1; window['result_aaa818ee5983f7b9']['jobStateChangedToSaved'] = false; window['result_aaa818ee5983f7b9']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['result_aaa818ee5983f7b9']['basicPermaLink'] = "https://au.indeed.com"; window['result_aaa818ee5983f7b9']['saveJobFailed'] = false; window['result_aaa818ee5983f7b9']['removeJobFailed'] = false; window['result_aaa818ee5983f7b9']['requestPending'] = false; window['result_aaa818ee5983f7b9']['notesEnabled'] = true; window['result_aaa818ee5983f7b9']['currentPage'] = "serp"; window['result_aaa818ee5983f7b9']['sponsored'] = false;window['result_aaa818ee5983f7b9']['reportJobButtonEnabled'] = false; window['result_aaa818ee5983f7b9']['showMyJobsHired'] = false; window['result_aaa818ee5983f7b9']['showSaveForSponsored'] = false; window['result_aaa818ee5983f7b9']['showJobAge'] = true; window['result_aaa818ee5983f7b9']['showHolisticCard'] = true; window['result_aaa818ee5983f7b9']['showDislike'] = false; window['result_aaa818ee5983f7b9']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="more-links-container result-tab" id="tt_display_1" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('aaa818ee5983f7b9'); return false;" title="Close"></a><div class="more_actions" id="more_1"><ul><li><span class="mat">View all <a href="/Queensland-Government-jobs">Queensland Government jobs</a> - <a href="/jobs-in-Logan-City-QLD">Logan City jobs</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Queensland-Government" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=aaa818ee5983f7b9&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=033d5c6dd090c8a4');">Queensland Government</a></span></li><li><span class="mat">See popular <a href="/cmp/Queensland-Government/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=aaa818ee5983f7b9&amp;jcid=033d5c6dd090c8a4');">questions &amp; answers about Queensland Government</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  <div class="sign-in-container result-tab"></div>
#  <div class="notes-container result-tab"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="3d1e3441933c1797" data-tn-component="organicJob" id="p_3d1e3441933c1797">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=3d1e3441933c1797&amp;fccid=ca2b244e2a15ca5c&amp;vjs=3" id="jl_3d1e3441933c1797" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="noopener nofollow" target="_blank" title="Data Analyst">
#  <b>Data</b> <b>Analyst</b></a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  Experis</span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Sydney Central Business District NSW" id="recJobLoc_3d1e3441933c1797" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Sydney Central Business District NSW</span>
#  </div>
#  <table class="jobCardShelfContainer"><tr class="jobCardShelf"><td class="jobCardShelfItem"><span class="iaLabel">Easily apply to this job</span></td></tr></table><div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li style="margin-bottom:0px;">Profile <b>data</b> and map out <b>data</b> lineage.</li>
#  <li style="margin-bottom:0px;">Understand <b>data</b> requirements both new and from the existing <b>data</b> warehouse.</li>
#  <li>Knowledge of <b>data</b> modelling applications.</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_2"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_3d1e3441933c1797" onclick="changeJobState('3d1e3441933c1797', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_2" onclick="toggleMoreLinks('3d1e3441933c1797'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_3d1e3441933c1797" style="display:none;"></div><script>if (!window['result_3d1e3441933c1797']) {window['result_3d1e3441933c1797'] = {};}window['result_3d1e3441933c1797']['showSource'] = false; window['result_3d1e3441933c1797']['source'] = "Experis"; window['result_3d1e3441933c1797']['loggedIn'] = false; window['result_3d1e3441933c1797']['showMyJobsLinks'] = false;window['result_3d1e3441933c1797']['undoAction'] = "unsave";window['result_3d1e3441933c1797']['relativeJobAge'] = "Just posted";window['result_3d1e3441933c1797']['jobKey'] = "3d1e3441933c1797"; window['result_3d1e3441933c1797']['myIndeedAvailable'] = true; window['result_3d1e3441933c1797']['showMoreActionsLink'] = window['result_3d1e3441933c1797']['showMoreActionsLink'] || true; window['result_3d1e3441933c1797']['resultNumber'] = 2; window['result_3d1e3441933c1797']['jobStateChangedToSaved'] = false; window['result_3d1e3441933c1797']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['result_3d1e3441933c1797']['basicPermaLink'] = "https://au.indeed.com"; window['result_3d1e3441933c1797']['saveJobFailed'] = false; window['result_3d1e3441933c1797']['removeJobFailed'] = false; window['result_3d1e3441933c1797']['requestPending'] = false; window['result_3d1e3441933c1797']['notesEnabled'] = true; window['result_3d1e3441933c1797']['currentPage'] = "serp"; window['result_3d1e3441933c1797']['sponsored'] = false;window['result_3d1e3441933c1797']['reportJobButtonEnabled'] = false; window['result_3d1e3441933c1797']['showMyJobsHired'] = false; window['result_3d1e3441933c1797']['showSaveForSponsored'] = false; window['result_3d1e3441933c1797']['showJobAge'] = true; window['result_3d1e3441933c1797']['showHolisticCard'] = true; window['result_3d1e3441933c1797']['showDislike'] = false; window['result_3d1e3441933c1797']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="more-links-container result-tab" id="tt_display_2" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('3d1e3441933c1797'); return false;" title="Close"></a><div class="more_actions" id="more_2"><ul><li><span class="mat">View all <a href="/Experis-jobs">Experis jobs</a> - <a href="/jobs-in-Sydney-Central-Business-District-NSW">Sydney Central Business District jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-analyst-Salaries,-Sydney-Central-Business-District-NSW" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=3d1e3441933c1797&amp;from=serp-more');">Data Analyst salaries in Sydney Central Business District NSW</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Experis" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=3d1e3441933c1797&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=ca2b244e2a15ca5c');">Experis</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  <div class="sign-in-container result-tab"></div>
#  <div class="notes-container result-tab"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="b49abb9d18e8a791" data-tn-component="organicJob" id="p_b49abb9d18e8a791">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=b49abb9d18e8a791&amp;fccid=3722a312e68001d5&amp;vjs=3" id="jl_b49abb9d18e8a791" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="noopener nofollow" target="_blank" title="Senior Analyst Tableau">
#  Senior <b>Analyst</b> Tableau</a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Coca--cola-Amatil" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=b49abb9d18e8a791&amp;jcid=3722a312e68001d5')" rel="noopener" target="_blank">
#  Coca-Cola Amatil</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Coca--cola-Amatil/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Senior+Analyst+Tableau&amp;fromjk=b49abb9d18e8a791&amp;jcid=3722a312e68001d5');" rel="noopener" target="_blank" title="Coca-cola Amatil reviews">
#  <span class="ratingsContent">
#  3.9<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Australia" id="recJobLoc_b49abb9d18e8a791" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Australia</span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li>A passion for making a positive impact in the <b>business</b>, translating <b>data</b> into impactful insights that can drive improved operational performance in the business…</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_3"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_b49abb9d18e8a791" onclick="changeJobState('b49abb9d18e8a791', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_3" onclick="toggleMoreLinks('b49abb9d18e8a791'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_b49abb9d18e8a791" style="display:none;"></div><script>if (!window['result_b49abb9d18e8a791']) {window['result_b49abb9d18e8a791'] = {};}window['result_b49abb9d18e8a791']['showSource'] = false; window['result_b49abb9d18e8a791']['source'] = "Coca-Cola Amatil"; window['result_b49abb9d18e8a791']['loggedIn'] = false; window['result_b49abb9d18e8a791']['showMyJobsLinks'] = false;window['result_b49abb9d18e8a791']['undoAction'] = "unsave";window['result_b49abb9d18e8a791']['relativeJobAge'] = "Just posted";window['result_b49abb9d18e8a791']['jobKey'] = "b49abb9d18e8a791"; window['result_b49abb9d18e8a791']['myIndeedAvailable'] = true; window['result_b49abb9d18e8a791']['showMoreActionsLink'] = window['result_b49abb9d18e8a791']['showMoreActionsLink'] || true; window['result_b49abb9d18e8a791']['resultNumber'] = 3; window['result_b49abb9d18e8a791']['jobStateChangedToSaved'] = false; window['result_b49abb9d18e8a791']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['result_b49abb9d18e8a791']['basicPermaLink'] = "https://au.indeed.com"; window['result_b49abb9d18e8a791']['saveJobFailed'] = false; window['result_b49abb9d18e8a791']['removeJobFailed'] = false; window['result_b49abb9d18e8a791']['requestPending'] = false; window['result_b49abb9d18e8a791']['notesEnabled'] = true; window['result_b49abb9d18e8a791']['currentPage'] = "serp"; window['result_b49abb9d18e8a791']['sponsored'] = false;window['result_b49abb9d18e8a791']['reportJobButtonEnabled'] = false; window['result_b49abb9d18e8a791']['showMyJobsHired'] = false; window['result_b49abb9d18e8a791']['showSaveForSponsored'] = false; window['result_b49abb9d18e8a791']['showJobAge'] = true; window['result_b49abb9d18e8a791']['showHolisticCard'] = true; window['result_b49abb9d18e8a791']['showDislike'] = false; window['result_b49abb9d18e8a791']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="more-links-container result-tab" id="tt_display_3" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('b49abb9d18e8a791'); return false;" title="Close"></a><div class="more_actions" id="more_3"><ul><li><span class="mat">View all <a href="/jobs?q=Coca-cola+Amatil">Coca-Cola Amatil jobs</a> - <a href="/jobs-in-Australia">Australia jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/senior-analyst-Salaries,-AU" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=b49abb9d18e8a791&amp;from=serp-more');">Senior Analyst salaries in Australia</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Coca--cola-Amatil" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=b49abb9d18e8a791&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=3722a312e68001d5');">Coca-Cola Amatil</a></span></li><li><span class="mat">See popular <a href="/cmp/Coca--cola-Amatil/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=b49abb9d18e8a791&amp;jcid=3722a312e68001d5');">questions &amp; answers about Coca-Cola Amatil</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  <div class="sign-in-container result-tab"></div>
#  <div class="notes-container result-tab"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="359df2b9e3261626" data-tn-component="organicJob" id="p_359df2b9e3261626">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=359df2b9e3261626&amp;fccid=26f47cce54403a22&amp;vjs=3" id="jl_359df2b9e3261626" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="noopener nofollow" target="_blank" title="Data Management Delivery Manager">
#  <b>Data</b> Management Delivery Manager</a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Commonwealth-Bank" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=359df2b9e3261626&amp;jcid=26f47cce54403a22')" rel="noopener" target="_blank">
#  Commonwealth Bank</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Commonwealth-Bank/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Management+Delivery+Manager&amp;fromjk=359df2b9e3261626&amp;jcid=26f47cce54403a22');" rel="noopener" target="_blank" title="Commonwealth Bank reviews">
#  <span class="ratingsContent">
#  4.0<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Sydney Central Business District NSW" id="recJobLoc_359df2b9e3261626" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Sydney Central Business District NSW</span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li>The CFS <b>Data</b> Office will enable our <b>business</b> to deliver better member outcomes by ensuring we have best-practice <b>data</b> management and <b>data</b> governance practices…</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_4"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_359df2b9e3261626" onclick="changeJobState('359df2b9e3261626', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_4" onclick="toggleMoreLinks('359df2b9e3261626'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_359df2b9e3261626" style="display:none;"></div><script>if (!window['result_359df2b9e3261626']) {window['result_359df2b9e3261626'] = {};}window['result_359df2b9e3261626']['showSource'] = false; window['result_359df2b9e3261626']['source'] = "Commonwealth Bank"; window['result_359df2b9e3261626']['loggedIn'] = false; window['result_359df2b9e3261626']['showMyJobsLinks'] = false;window['result_359df2b9e3261626']['undoAction'] = "unsave";window['result_359df2b9e3261626']['relativeJobAge'] = "Just posted";window['result_359df2b9e3261626']['jobKey'] = "359df2b9e3261626"; window['result_359df2b9e3261626']['myIndeedAvailable'] = true; window['result_359df2b9e3261626']['showMoreActionsLink'] = window['result_359df2b9e3261626']['showMoreActionsLink'] || true; window['result_359df2b9e3261626']['resultNumber'] = 4; window['result_359df2b9e3261626']['jobStateChangedToSaved'] = false; window['result_359df2b9e3261626']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['result_359df2b9e3261626']['basicPermaLink'] = "https://au.indeed.com"; window['result_359df2b9e3261626']['saveJobFailed'] = false; window['result_359df2b9e3261626']['removeJobFailed'] = false; window['result_359df2b9e3261626']['requestPending'] = false; window['result_359df2b9e3261626']['notesEnabled'] = true; window['result_359df2b9e3261626']['currentPage'] = "serp"; window['result_359df2b9e3261626']['sponsored'] = false;window['result_359df2b9e3261626']['reportJobButtonEnabled'] = false; window['result_359df2b9e3261626']['showMyJobsHired'] = false; window['result_359df2b9e3261626']['showSaveForSponsored'] = false; window['result_359df2b9e3261626']['showJobAge'] = true; window['result_359df2b9e3261626']['showHolisticCard'] = true; window['result_359df2b9e3261626']['showDislike'] = false; window['result_359df2b9e3261626']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="more-links-container result-tab" id="tt_display_4" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('359df2b9e3261626'); return false;" title="Close"></a><div class="more_actions" id="more_4"><ul><li><span class="mat">View all <a href="/Commonwealth-Bank-jobs">Commonwealth Bank jobs</a> - <a href="/jobs-in-Sydney-Central-Business-District-NSW">Sydney Central Business District jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/data-manager-Salaries,-Sydney-Central-Business-District-NSW" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=359df2b9e3261626&amp;from=serp-more');">Data Manager salaries in Sydney Central Business District NSW</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Commonwealth-Bank" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=359df2b9e3261626&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=26f47cce54403a22');">Commonwealth Bank</a></span></li><li><span class="mat">See popular <a href="/cmp/Commonwealth-Bank/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=359df2b9e3261626&amp;jcid=26f47cce54403a22');">questions &amp; answers about Commonwealth Bank</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  <div class="sign-in-container result-tab"></div>
#  <div class="notes-container result-tab"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="1914ae6d6adb3c70" data-tn-component="organicJob" id="p_1914ae6d6adb3c70">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=1914ae6d6adb3c70&amp;fccid=9605a3534a186df0&amp;vjs=3" id="jl_1914ae6d6adb3c70" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="noopener nofollow" target="_blank" title="Procurement Analytics &amp; Insights Specialist">
#  Procurement <b>Analytics</b> &amp; Insights Specialist</a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Fortescue-Metals-Group" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=1914ae6d6adb3c70&amp;jcid=9605a3534a186df0')" rel="noopener" target="_blank">
#  Fortescue Metals Group</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Fortescue-Metals-Group/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Procurement+Analytics+%26+Insights+Specialist&amp;fromjk=1914ae6d6adb3c70&amp;jcid=9605a3534a186df0');" rel="noopener" target="_blank" title="Fortescue Metals Group reviews">
#  <span class="ratingsContent">
#  3.9<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Perth WA" id="recJobLoc_1914ae6d6adb3c70" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Perth WA</span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li>With your advance <b>data</b> <b>analytics</b> skills, topped off with enthusiasm and a strong customer focus, this position will present you with the opportunity to…</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_5"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_1914ae6d6adb3c70" onclick="changeJobState('1914ae6d6adb3c70', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_5" onclick="toggleMoreLinks('1914ae6d6adb3c70'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_1914ae6d6adb3c70" style="display:none;"></div><script>if (!window['result_1914ae6d6adb3c70']) {window['result_1914ae6d6adb3c70'] = {};}window['result_1914ae6d6adb3c70']['showSource'] = false; window['result_1914ae6d6adb3c70']['source'] = "Fortescue Metals Group"; window['result_1914ae6d6adb3c70']['loggedIn'] = false; window['result_1914ae6d6adb3c70']['showMyJobsLinks'] = false;window['result_1914ae6d6adb3c70']['undoAction'] = "unsave";window['result_1914ae6d6adb3c70']['relativeJobAge'] = "Just posted";window['result_1914ae6d6adb3c70']['jobKey'] = "1914ae6d6adb3c70"; window['result_1914ae6d6adb3c70']['myIndeedAvailable'] = true; window['result_1914ae6d6adb3c70']['showMoreActionsLink'] = window['result_1914ae6d6adb3c70']['showMoreActionsLink'] || true; window['result_1914ae6d6adb3c70']['resultNumber'] = 5; window['result_1914ae6d6adb3c70']['jobStateChangedToSaved'] = false; window['result_1914ae6d6adb3c70']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['result_1914ae6d6adb3c70']['basicPermaLink'] = "https://au.indeed.com"; window['result_1914ae6d6adb3c70']['saveJobFailed'] = false; window['result_1914ae6d6adb3c70']['removeJobFailed'] = false; window['result_1914ae6d6adb3c70']['requestPending'] = false; window['result_1914ae6d6adb3c70']['notesEnabled'] = true; window['result_1914ae6d6adb3c70']['currentPage'] = "serp"; window['result_1914ae6d6adb3c70']['sponsored'] = false;window['result_1914ae6d6adb3c70']['reportJobButtonEnabled'] = false; window['result_1914ae6d6adb3c70']['showMyJobsHired'] = false; window['result_1914ae6d6adb3c70']['showSaveForSponsored'] = false; window['result_1914ae6d6adb3c70']['showJobAge'] = true; window['result_1914ae6d6adb3c70']['showHolisticCard'] = true; window['result_1914ae6d6adb3c70']['showDislike'] = false; window['result_1914ae6d6adb3c70']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="more-links-container result-tab" id="tt_display_5" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('1914ae6d6adb3c70'); return false;" title="Close"></a><div class="more_actions" id="more_5"><ul><li><span class="mat">View all <a href="/Fortescue-Metals-Group-jobs">Fortescue Metals Group jobs</a> - <a href="/jobs-in-Perth-WA">Perth jobs</a></span></li><li><span class="mat">Salary Search: <a href="/salaries/procurement-specialist-Salaries,-Perth-WA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=1914ae6d6adb3c70&amp;from=serp-more');">Procurement Specialist salaries in Perth WA</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Fortescue-Metals-Group" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=1914ae6d6adb3c70&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=9605a3534a186df0');">Fortescue Metals Group</a></span></li><li><span class="mat">See popular <a href="/cmp/Fortescue-Metals-Group/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=1914ae6d6adb3c70&amp;jcid=9605a3534a186df0');">questions &amp; answers about Fortescue Metals Group</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  <div class="sign-in-container result-tab"></div>
#  <div class="notes-container result-tab"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="31dfefdaa57933bb" data-tn-component="organicJob" id="p_31dfefdaa57933bb">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=31dfefdaa57933bb&amp;fccid=31670bef3ae6497b&amp;vjs=3" id="jl_31dfefdaa57933bb" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="noopener nofollow" target="_blank" title="Data Engineer">
#  <b>Data</b> <b>Engineer</b></a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Hays" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=31dfefdaa57933bb&amp;jcid=31670bef3ae6497b')" rel="noopener" target="_blank">
#  HAYS</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Hays/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Engineer&amp;fromjk=31dfefdaa57933bb&amp;jcid=31670bef3ae6497b');" rel="noopener" target="_blank" title="Hays reviews">
#  <span class="ratingsContent">
#  3.6<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Gold Coast QLD" id="recJobLoc_31dfefdaa57933bb" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Gold Coast QLD</span>
#  <span>
#  <a class="more_loc" href="/addlLoc/redirect?tk=1e1jb60e310jp000&amp;jk=31dfefdaa57933bb&amp;dest=%2Fjobs%3Fq%3D%2528python%2Bor%2Bsql%2529%2B%2B%2528data%2Bor%2Bscientist%2Bor%2Bscience%2Bor%2Banalyst%2Bor%2Bresearch%2Bor%2Bbusiness%2Bor%2Bintelligence%2Bor%2Banalytics%2Bor%2Bstatistics%2Bor%2BActuarial%2Bor%2Bactuary%2Bor%2B%2522data%2Bengineer%2522%2529%2B-developer%252C%2B-clerk%252C%2B-software%252C%2B-network%252C%2B-security%252C%2B-programmer%26rbt%3DData%2BEngineer%26rbc%3DHAYS%26jtid%3Dd9d2485aed98da24%26jcid%3D31670bef3ae6497b%26sort%3Ddate%26limit%3D50%26grp%3Dtcl" onmousedown="ptk('addlloc');" rel="nofollow">
#  +1 location</a>
#  </span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li style="margin-bottom:0px;">Working with Agile teams to properly define and understand <b>business</b> requirements from a <b>data</b> perspective.</li>
#  <li>Extracting <b>data</b> from APIs (C# or other programmatical…</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="date">Just posted</span><span class="tt_set" id="tt_set_6"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_31dfefdaa57933bb" onclick="changeJobState('31dfefdaa57933bb', 'save', 'linkbar', false, ''); return false;" title="Save this job to my.indeed">Save job</a><span class="result-link-bar-separator">·</span><a class="sl resultLink more-link" href="#" id="tog_6" onclick="toggleMoreLinks('31dfefdaa57933bb'); return false;">more...</a></span><div class="edit_note_content" id="editsaved2_31dfefdaa57933bb" style="display:none;"></div><script>if (!window['result_31dfefdaa57933bb']) {window['result_31dfefdaa57933bb'] = {};}window['result_31dfefdaa57933bb']['showSource'] = false; window['result_31dfefdaa57933bb']['source'] = "Hays"; window['result_31dfefdaa57933bb']['loggedIn'] = false; window['result_31dfefdaa57933bb']['showMyJobsLinks'] = false;window['result_31dfefdaa57933bb']['undoAction'] = "unsave";window['result_31dfefdaa57933bb']['relativeJobAge'] = "Just posted";window['result_31dfefdaa57933bb']['jobKey'] = "31dfefdaa57933bb"; window['result_31dfefdaa57933bb']['myIndeedAvailable'] = true; window['result_31dfefdaa57933bb']['showMoreActionsLink'] = window['result_31dfefdaa57933bb']['showMoreActionsLink'] || true; window['result_31dfefdaa57933bb']['resultNumber'] = 6; window['result_31dfefdaa57933bb']['jobStateChangedToSaved'] = false; window['result_31dfefdaa57933bb']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['result_31dfefdaa57933bb']['basicPermaLink'] = "https://au.indeed.com"; window['result_31dfefdaa57933bb']['saveJobFailed'] = false; window['result_31dfefdaa57933bb']['removeJobFailed'] = false; window['result_31dfefdaa57933bb']['requestPending'] = false; window['result_31dfefdaa57933bb']['notesEnabled'] = true; window['result_31dfefdaa57933bb']['currentPage'] = "serp"; window['result_31dfefdaa57933bb']['sponsored'] = false;window['result_31dfefdaa57933bb']['reportJobButtonEnabled'] = false; window['result_31dfefdaa57933bb']['showMyJobsHired'] = false; window['result_31dfefdaa57933bb']['showSaveForSponsored'] = false; window['result_31dfefdaa57933bb']['showJobAge'] = true; window['result_31dfefdaa57933bb']['showHolisticCard'] = true; window['result_31dfefdaa57933bb']['showDislike'] = false; window['result_31dfefdaa57933bb']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="more-links-container result-tab" id="tt_display_6" style="display:none;"><a class="close-link closeLink" href="#" onclick="toggleMoreLinks('31dfefdaa57933bb'); return false;" title="Close"></a><div class="more_actions" id="more_6"><ul><li><span class="mat">View all <a href="/Hays-jobs">HAYS jobs</a> - <a href="/jobs-in-Gold-Coast-QLD">Gold Coast jobs</a></span></li><li><span class="mat">Learn more about working at <a href="/cmp/Hays" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=31dfefdaa57933bb&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=31670bef3ae6497b');">HAYS</a></span></li><li><span class="mat">See popular <a href="/cmp/Hays/faq" onmousedown="this.href = appendParamsOnce(this.href, '?from=serp-more&amp;campaignid=serp-more&amp;fromjk=31dfefdaa57933bb&amp;jcid=31670bef3ae6497b');">questions &amp; answers about HAYS</a></span></li></ul></div></div><div class="dya-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  <div class="sign-in-container result-tab"></div>
#  <div class="notes-container result-tab"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-jk="960e2575afb075d4" data-tn-component="organicJob" id="p_960e2575afb075d4">
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=960e2575afb075d4&amp;fccid=03cacc905f5db444&amp;vjs=3" id="jl_960e2575afb075d4" onclick="setRefineByCookie(['radius']); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="noopener nofollow" target="_blank" title="Performance Support Analyst">
#  Performance Support <b>Analyst</b></a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/BP" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=960e2575afb075d4&amp;jcid=03cacc905f5db444')" rel="noopener" target="_blank">
#  BP</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/BP/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Performance+Support+Analyst&amp;fromjk=960e2575afb075d4&amp;jcid=03cacc905f5db444');" rel="noopener" target="_blank" title="BP reviews">
#  <span class="ratingsContent">
#  3.9<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Melbourne VIC" id="recJobLoc_960e2575afb075d4" style="display: none"></div>
#  <span class="location accessible-contrast-color-location">Melbourne VIC</span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
# ...
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="sign-in-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="334611951" data-empn="7437259568711229" data-jk="836097415eb1f566" id="pj_836097415eb1f566">
#  <style>
#  .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}
#  </style>
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0A6NPejaqZ1yit9NQkOiWw0j6WyN4wTsxer7KHR4mPcXKwgkFgRPX2MUexaXq734LEnV9i60owQQP7MKEPZYKNJTHaMQ6n3SMc4j2ygxBOgxEI1Ep6FcBcqOPfeSdTlEP655Xgd0OdbmOrU_Ia0Vs61-p2Ael2TdF3j2Bow1i7kqcGwNhZRwePlW73T08EtQKTh2FIE-0_G62aPGwAVgYajgvt-iM8kcmE8Sd4MnEiaRzdy4guLUUeRTtZB6OHgt8rilEjVaaU6XVEtzLPGrrWmu844NewlsHstTG8qH8YCbzyUs471mPc3ZtaQt2HQmafmDDpjQwRqC8x6sI0FHRtjSwYKhPC_e4fraE_0jRHfeo5n_G7dwz81MznmS7siS_wLg31VyYelMfwz77EDr9mf6Ep9ydjXtuiErNBqSmsoDVxw9IpJjh3-04Fh1hVzdipYyRmZlmsyj6sDDTEc08iv_DlnmG0bVzdsxIcMVqiSc2Rsmox7NdbGABeEA-oMmF0uYBsDo8dWrkMxR1rHqtEkpPpscKsKELS7u42boaS2ITrCKOGz_SxHs1PwQwmYUJAKdYXKNjsmafIhYrNikWKYbZGfXAZwGeV3Fl8kxdL8UcEheW_fPjjpTIn3nJ1CrMPSXMCmrnA6KUp2j0C9GWu8H1gBhgQLlaSWxaYcRoRL7oMSPcZlwASMrM1yGGo_lqTdUhYBo-lsxon-ReNFkTQ2jl3PgiGfOpsUwnxJfe2zEW9DxoxwxyK-pBNdv88MR-34P-a9xvGP8Uwus2LbaFxAZzpJbW__bCeWCcQxMW81rvwsJ5OcMHY1HR1FuQ-ODTnTCz3ph7E0d7THPVaGNkHUTSec9v4oRi9R5UM_TEWSSuWcTloCEJmJc6szN1ljYmSkYNj1fw9WvJ02LcjfksEpdP8HXc9rWIpB2VNWetxzol-rtz4KBjQcI9fx_2S6nDvmunGklyYKP9q_P_kQFPMHOX-_TQuHn8cYxuw9fqwtkIullTSGTV7IpNxwm7RofsQ=&amp;p=52&amp;fvj=0&amp;vjs=3" id="sja52" onclick="setRefineByCookie(['radius']); sjoc('sja52', 1); convCtr('SJ'); rclk(this,jobmap[52],true,1);" onmousedown="sjomd('sja52'); clk('sja52'); rclk(this,jobmap[52],1);" rel="noopener nofollow" target="_blank" title="Transactional Data Analyst">
#  Transactional <b>Data</b> <b>Analyst</b></a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Robert-Half" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=836097415eb1f566&amp;jcid=d3588ffda1f22425')" rel="noopener" target="_blank">
#  Robert Half Australia</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/Robert-Half/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Transactional+Data+Analyst&amp;fromjk=836097415eb1f566&amp;jcid=d3588ffda1f22425');" rel="noopener" target="_blank" title="Robert Half Australia reviews">
#  <span class="ratingsContent">
#  3.9<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Parramatta NSW" id="recJobLoc_836097415eb1f566" style="display: none"></div>
#  <div class="location accessible-contrast-color-location">Parramatta NSW</div>
#  </div>
#  <div class="salarySnippet salarySnippetDemphasizeholisticSalary">
#  <span class="salary no-wrap">
#  <span class="salaryText">
#  $65,000 a year</span>
#  </span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li style="margin-bottom:0px;">Analyze transactional <b>data</b> to identify errors in transactional services.</li>
#  <li>Executing Pivot Tables in Excel to manipulate <b>data</b> and identify service errors.</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="date">17 days ago</span><span class="tt_set" id="tt_set_52"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_836097415eb1f566" onclick="changeJobState('836097415eb1f566', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_836097415eb1f566" style="display:none;"></div><script>if (!window['sj_result_836097415eb1f566']) {window['sj_result_836097415eb1f566'] = {};}window['sj_result_836097415eb1f566']['showSource'] = false; window['sj_result_836097415eb1f566']['source'] = "Robert Half Australia"; window['sj_result_836097415eb1f566']['loggedIn'] = false; window['sj_result_836097415eb1f566']['showMyJobsLinks'] = false;window['sj_result_836097415eb1f566']['undoAction'] = "unsave";window['sj_result_836097415eb1f566']['relativeJobAge'] = "17 days ago";window['sj_result_836097415eb1f566']['jobKey'] = "836097415eb1f566"; window['sj_result_836097415eb1f566']['myIndeedAvailable'] = true; window['sj_result_836097415eb1f566']['showMoreActionsLink'] = window['sj_result_836097415eb1f566']['showMoreActionsLink'] || false; window['sj_result_836097415eb1f566']['resultNumber'] = 52; window['sj_result_836097415eb1f566']['jobStateChangedToSaved'] = false; window['sj_result_836097415eb1f566']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['sj_result_836097415eb1f566']['basicPermaLink'] = "https://au.indeed.com"; window['sj_result_836097415eb1f566']['saveJobFailed'] = false; window['sj_result_836097415eb1f566']['removeJobFailed'] = false; window['sj_result_836097415eb1f566']['requestPending'] = false; window['sj_result_836097415eb1f566']['notesEnabled'] = false; window['sj_result_836097415eb1f566']['currentPage'] = "serp"; window['sj_result_836097415eb1f566']['sponsored'] = true;window['sj_result_836097415eb1f566']['showSponsor'] = true;window['sj_result_836097415eb1f566']['reportJobButtonEnabled'] = false; window['sj_result_836097415eb1f566']['showMyJobsHired'] = false; window['sj_result_836097415eb1f566']['showSaveForSponsored'] = true; window['sj_result_836097415eb1f566']['showJobAge'] = true; window['sj_result_836097415eb1f566']['showHolisticCard'] = true; window['sj_result_836097415eb1f566']['showDislike'] = false; window['sj_result_836097415eb1f566']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="sign-in-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  </div>
#  </div>,
#  <div class="jobsearch-SerpJobCard unifiedRow row result" data-ci="300818348" data-empn="3241536477265761" data-jk="ec7edefe63b41ca5" id="pj_ec7edefe63b41ca5">
#  <style>
#  .jobcard_logo{margin:6px 0}.jobcard_logo img{width:auto;max-width:80px;max-height:30px}
#  </style>
#  <div class="title">
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0B7ITBqJTanqBsjVN78KnfcnRrbZaN6ubmg5ja68pbRmE22RBT1ggiUq_KYOoKXaUzxWoNpz9qWNjPv7hgd4oJdSPqogWqGX-MLH3f4SlCDTuVNcWloqR4PPIHLTcAdeE2S-ZajnmEoOxJNk7ZzWqz08WIUklYKiGe7NXmbbm3WkZK6jtwW8_fnmh8wOGiVaWAOg65pYwO-W3ZpF7LXKmNrZcCEqO4CgM2FDbss0MoGr6A4s7mFQEsf-4w0qr02MnIPPVeGv7wN5fb1ukoX_7N6oSnvor3qh5ePSuR5pZF-P56ImbpUyag-RG-C7mnqk-bRt7ZvsmbAIfNrp76okGD4WY3hG07_8Zhc7rWn4vVuh3umz1yePzRJkPKoS6P5OFJkNZx9h0b1zinhly6BMYInjTwgrBoXQIVSTzRX5iwiyqIUCS4fOPxXC4J1OfWESLTYaHtyjjVOp1pvJ88u3s2jZFttzC-nRLh2AoPr9nSDdFmdJHLJu-4RY25ul9q2-P9vJhHJtqTEdf1BHbjdOTyovaIwWeUeQtym0bIPi2mWHh9xBsbTbQKgSjTpZTK85VLPrwyZuFe8zpgd_RtqitaXlMgueXGfI68szTmjUwfOmq75MPiI7CM87j0kBDLqWxT2s1QmtoaYqR2-LBJOy95njqLoqUYb35e3Rrswoswp8-N-wSAdi77h97toefIppHaWMiUr5J07dg-0YNx1RH1KPDmx6bg9lcHKeIjcYSHiKhlRfQeczFsKHR4wC6kkhsq4kGIGkky9mWSEZgKd1GCScKRQEm3NDZtZAqTyfOaa0aSQ1k61jZxs4sGchohcHZI=&amp;p=53&amp;fvj=0&amp;vjs=3" id="sja53" onclick="setRefineByCookie(['radius']); sjoc('sja53', 1); convCtr('SJ'); rclk(this,jobmap[53],true,1);" onmousedown="sjomd('sja53'); clk('sja53'); rclk(this,jobmap[53],1);" rel="noopener nofollow" target="_blank" title="Educational Data Analyst">
#  Educational <b>Data</b> <b>Analyst</b></a>
#  </div>
#  <div class="sjcl">
#  <div>
#  <span class="company">
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/University-of-New-South-Wales" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=ec7edefe63b41ca5&amp;jcid=f7b9aa4f9b3d1c21')" rel="noopener" target="_blank">
#  University of New South Wales</a></span>
#  <span class="ratingsDisplay">
#  <a class="ratingNumber" data-tn-variant="cmplinktst2" href="/cmp/University-of-New-South-Wales/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Educational+Data+Analyst&amp;fromjk=ec7edefe63b41ca5&amp;jcid=f7b9aa4f9b3d1c21');" rel="noopener" target="_blank">
#  <span class="ratingsContent">
#  4.2<svg class="starIcon" height="12px" role="img" width="12px">
#  <g>
#  <path d="M 12.00,4.34 C 12.00,4.34 7.69,3.97 7.69,3.97 7.69,3.97 6.00,0.00 6.00,0.00 6.00,0.00 4.31,3.98 4.31,3.98 4.31,3.98 0.00,4.34 0.00,4.34 0.00,4.34 3.28,7.18 3.28,7.18 3.28,7.18 2.29,11.40 2.29,11.40 2.29,11.40 6.00,9.16 6.00,9.16 6.00,9.16 9.71,11.40 9.71,11.40 9.71,11.40 8.73,7.18 8.73,7.18 8.73,7.18 12.00,4.34 12.00,4.34 Z" style="fill: #FFB103"></path>
#  </g>
#  </svg>
#  </span>
#  </a>
#  </span>
#  </div>
#  <div class="recJobLoc" data-rc-loc="Sydney NSW" id="recJobLoc_ec7edefe63b41ca5" style="display: none"></div>
#  <div class="location accessible-contrast-color-location">Sydney NSW</div>
#  </div>
#  <div class="salarySnippet salarySnippetDemphasizeholisticSalary">
#  <span class="salary no-wrap">
#  <span class="salaryText">
#  $95,000 - $103,000 a year</span>
#  </span>
#  </div>
#  <div class="summary">
#  <ul style="list-style-type:circle;margin-top: 0px;margin-bottom: 0px;padding-left:20px;">
#  <li style="margin-bottom:0px;">Good knowledge of working with <b>data</b>: <b>data</b> structures, <b>data</b> representation, <b>data</b> cleaning, <b>data</b> governance, and database design.</li>
#  <li>Full-time (1FTE, 35hrs p/week).</li>
#  </ul></div>
#  <div class="jobsearch-SerpJobCard-footer">
#  <div class="jobsearch-SerpJobCard-footerActions">
#  <div class="result-link-bar-container">
#  <div class="result-link-bar"><span class="sponsoredGray">Sponsored</span><span class="result-link-bar-separator hide-sponsored-separator">·</span><span class="date">8 days ago</span><span class="tt_set" id="tt_set_53"><span class="result-link-bar-separator">·</span><a class="sl resultLink save-job-link" href="#" id="sj_ec7edefe63b41ca5" onclick="changeJobState('ec7edefe63b41ca5', 'save', 'linkbar', true, ''); return false;" title="Save this job to my.indeed">Save job</a></span><div class="edit_note_content" id="editsaved2_ec7edefe63b41ca5" style="display:none;"></div><script>if (!window['sj_result_ec7edefe63b41ca5']) {window['sj_result_ec7edefe63b41ca5'] = {};}window['sj_result_ec7edefe63b41ca5']['showSource'] = false; window['sj_result_ec7edefe63b41ca5']['source'] = "University of New South Wales"; window['sj_result_ec7edefe63b41ca5']['loggedIn'] = false; window['sj_result_ec7edefe63b41ca5']['showMyJobsLinks'] = false;window['sj_result_ec7edefe63b41ca5']['undoAction'] = "unsave";window['sj_result_ec7edefe63b41ca5']['relativeJobAge'] = "8 days ago";window['sj_result_ec7edefe63b41ca5']['jobKey'] = "ec7edefe63b41ca5"; window['sj_result_ec7edefe63b41ca5']['myIndeedAvailable'] = true; window['sj_result_ec7edefe63b41ca5']['showMoreActionsLink'] = window['sj_result_ec7edefe63b41ca5']['showMoreActionsLink'] || false; window['sj_result_ec7edefe63b41ca5']['resultNumber'] = 53; window['sj_result_ec7edefe63b41ca5']['jobStateChangedToSaved'] = false; window['sj_result_ec7edefe63b41ca5']['searchState'] = "q=(python or sql)  (data or scientist or science or analyst or research or business or intelligence or analytics or statistics or Actuarial or actuary or &quot;data engineer&quot;) -developer, -clerk, -software, -network, -security, -programmer&amp;sort=date&amp;radius=50&amp;limit=50"; window['sj_result_ec7edefe63b41ca5']['basicPermaLink'] = "https://au.indeed.com"; window['sj_result_ec7edefe63b41ca5']['saveJobFailed'] = false; window['sj_result_ec7edefe63b41ca5']['removeJobFailed'] = false; window['sj_result_ec7edefe63b41ca5']['requestPending'] = false; window['sj_result_ec7edefe63b41ca5']['notesEnabled'] = false; window['sj_result_ec7edefe63b41ca5']['currentPage'] = "serp"; window['sj_result_ec7edefe63b41ca5']['sponsored'] = true;window['sj_result_ec7edefe63b41ca5']['showSponsor'] = true;window['sj_result_ec7edefe63b41ca5']['reportJobButtonEnabled'] = false; window['sj_result_ec7edefe63b41ca5']['showMyJobsHired'] = false; window['sj_result_ec7edefe63b41ca5']['showSaveForSponsored'] = true; window['sj_result_ec7edefe63b41ca5']['showJobAge'] = true; window['sj_result_ec7edefe63b41ca5']['showHolisticCard'] = true; window['sj_result_ec7edefe63b41ca5']['showDislike'] = false; window['sj_result_ec7edefe63b41ca5']['showKebab'] = false;</script></div></div>
#  </div>
#  </div>
#  <div class="tab-container">
#  <div class="sign-in-container result-tab"></div>
#  <div class="tellafriend-container result-tab email_job_content"></div>
#  </div>
#  </div>]

# %%
a class="jobtitle turnstileLink" data-tn-element="jobTitle"

# %%
for p_job in link_indeed:
    salary = p_job.find('span', attrs={'class': 'salaryText'}).text
    print(salary)
#     try:
#         salary = p_job.find(attrs={'class': 'salaryText'}).text
#         print(salary) 
#     except:
#         print('none')
#     title = p_job.find('a', attrs={'data-tn-element': "jobTitle"}).get('title')
#     print (title)
# Out:
# $83,478 - $92,146 a year
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-9bc7ad01532c> in <module>
#       1 for p_job in link_indeed:
# ----> 2     salary = p_job.find('span', attrs={'class': 'salaryText'}).text
#       3     print(salary)
#       4 #     try:
#       5 #         salary = p_job.find(attrs={'class': 'salaryText'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
salary
# Out:
# []

# %%
while next_button_len == 2:
    
    for p_job in link_indeed:
        row = {}
        join_site = [job_site, p_job.find('a')['href']]
        new_url = ''.join(join_site)
        new_soup = soup_req(new_url)

        row['job_title'] = new_soup.find('h3').text if new_soup.find('h3') else 'none'
        row['company_name'] = new_soup.find('div', attrs={'class': 'icl-u-lg-mr--sm icl-u-xs-mr--xs'}).text if new_soup.find('div', attrs={'class': 'icl-u-lg-mr--sm icl-u-xs-mr--xs'}) else 'none'
        row['location'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[0].text if new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'}) else 'none'

        class_len = len(new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'}))
        salary = 'none'
        position = 'none'

        for i in range(1,class_len):

            if i == 1:
                row['salary'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[1].text
                if row['salary'][0] != '$':
                    row['position'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[1].text
                    row['salary'] = 'none'
            elif i == 2: 
                row['salary'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[2].text

        row['job_desc'] = new_soup.find('div', attrs={'class': 'jobsearch-JobComponent-description'}).text if new_soup.find('div', attrs={'class': 'jobsearch-JobComponent-description'}) else 'none'

        store_job.append(row)
    
    counter += 50
    page_count = counter 
    next_page = ''.join([url_indeed, start_page, str(page_count)])
    delay()
    soup_indeed = soup_req(next_page)
    
    link_indeed = soup_indeed.find_all('div', {'class': 'title'})
    next_button_len = len(soup_indeed.find_all('span', attrs={'class': 'np'}))

# %%
df_job = pd.DataFrame(store_job)
df_job.to_csv('Job_final_output_v5.csv')

# %%
counter
# Out:
# 950

# %%
next_page
# Out:
# 'https://au.indeed.com/jobs?as_and=data+engineer&as_phr=&as_any=&as_not=&as_ttl=&as_cmp=&jt=all&st=&as_src=&salary=&radius=50&l=&fromage=any&limit=50&sort=&psf=advsrch&from=advancedsearch&start=950'

# %%
df_job
# Out:
#                                   job_title            company_name  \
# 0             ICT Support and Test Engineer  EHW Technology Pty Ltd
# 1               Desktop Deployment Engineer               Muscatech
# 2         Windows Patch Management Engineer        Chandler Macleod
# 3                       Production Engineer          Jindex Pty Ltd
# 4       Electrical Engineering Draftsperson   UtilityVision Pty Ltd
# ...                                     ...                     ...
# 1015                           Scrum Master             PCCW Global
# 1016              Software Process Engineer                  Maptek
# 1017  Enterprise Sales Engineer - Singapore                 Datadog
# 1018          C4I Communications Specialist        Nova Systems ANZ
# 1019                      Bigdata Engineers         CellOS Software
#
#                      location                    salary              position  \
# 0                  Mackay QLD            $60,000 a year  Full-time, Permanent
# 1                Canberra ACT         $30 - $35 an hour   Casual, Subcontract
# 2               Melbourne VIC                      none              Contract
# 3     Frenchs Forest NSW 2086  $60,000 - $69,999 a year                   NaN
# 4             Craigieburn VIC   $35.00 - $39.99 an hour             Permanent
# ...                       ...                       ...                   ...
# 1015        Brisbane QLD 4000                      none  Full-time, Permanent
# 1016              Adelaide SA                       NaN                   NaN
# 1017               Sydney NSW                       NaN                   NaN
# 1018             Canberra ACT                       NaN                   NaN
# 1019            Melbourne VIC                       NaN                   NaN
#
#                                                job_desc
# 0     Mackay QLDFull-time, Permanent$60,000 a year\n...
# 1     Canberra ACTCasual, Subcontract$30 - $35 an ho...
# 2     Melbourne VICContract\n                try {\n...
# 3     Frenchs Forest NSW 2086$60,000 - $69,999 a yea...
# 4     Craigieburn VICPermanent$35.00 - $39.99 an hou...
# ...                                                 ...
# 1015  Brisbane QLD 4000Full-time, Permanent\n       ...
# 1016  Adelaide SA\n                try {\n          ...
# 1017  Sydney NSW\n                try {\n           ...
# 1018  Canberra ACT\n                try {\n         ...
# 1019  Melbourne VIC\n                try {\n        ...
#
# [1020 rows x 6 columns]

# %%
job_site = 'https://www.seek.com.au/'
start_page = '&start='
page_count = ''
counter = 50
store_job = []
next_button_len = 2

# %%
url_seek = 'https://www.seek.com.au/data-scientist-jobs?sortmode=KeywordRelevance'

# %%
soup_indeed = soup_req(url_seek)

# %%
soup_indeed.find_all('h1').find_all('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-db3eecee7512> in <module>
# ----> 1 soup_indeed.find_all('h1').find_all('a')
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
link_indeed = soup_indeed.find_all('div', {'class': 'title'})

# %%
while next_button_len == 2:
    
    for p_job in link_indeed:
        row = {}
        join_site = [job_site, p_job.find('a')['href']]
        new_url = ''.join(join_site)
        new_soup = soup_req(new_url)

        row['job_title'] = new_soup.find('h3').text if new_soup.find('h3') else 'none'
        row['company_name'] = new_soup.find('div', attrs={'class': 'icl-u-lg-mr--sm icl-u-xs-mr--xs'}).text if new_soup.find('div', attrs={'class': 'icl-u-lg-mr--sm icl-u-xs-mr--xs'}) else 'none'
        row['location'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[0].text if new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'}) else 'none'

        class_len = len(new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'}))
        salary = 'none'
        position = 'none'

        for i in range(1,class_len):

            if i == 1:
                row['salary'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[1].text
                if row['salary'][0] != '$':
                    row['position'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[1].text
                    row['salary'] = 'none'
            elif i == 2: 
                row['salary'] = new_soup.find_all(attrs={'class': 'jobsearch-JobMetadataHeader-iconLabel'})[2].text

        row['job_desc'] = new_soup.find('div', attrs={'class': 'jobsearch-JobComponent-description'}).text if new_soup.find('div', attrs={'class': 'jobsearch-JobComponent-description'}) else 'none'

        store_job.append(row)
    
    counter += 50
    page_count = counter 
    next_page = ''.join([url_indeed, start_page, str(page_count)])
    delay()
    soup_indeed = soup_req(next_page)
    
    link_indeed = soup_indeed.find_all('div', {'class': 'title'})
    next_button_len = len(soup_indeed.find_all('span', attrs={'class': 'np'}))
